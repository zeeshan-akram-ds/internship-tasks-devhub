# %% [markdown]
# # 1. Introduction and Problem Statement

# %% [markdown]
# ## Objective

# %% [markdown]
# ### This task involves exploring and visualizing a simple dataset to understand its structure, patterns, and relationships between variables.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### As a data scientist at a company, i am tasked with performing an initial data exploration on the classic Iris Dataset. My goal is to:
#
# - **Understand the structure and content of the dataset**
#
# - **Visualize relationships between features**
#
# - **Detect any outliers or data distribution patterns**
#
# #### This step is critical for making informed decisions in future modeling tasks such as classification of iris species based on flower measurements.

# %% [markdown]
# # 2. Dataset Understanding and Description

# %% [markdown]
# ### Dataset: Iris Dataset

# %% [markdown]
# - The Iris dataset is one of the most famous datasets in machine learning and statistics.
# - It consists of 150 rows and 5 columns, representing 3 species of Iris flowers.
# ### Features:
# - **sepal_length**
# - **sepal_width**
# - **petal_length**
# - **petal_width**
# - **species**
#
# #### Use Case:
# The dataset is often used to demonstrate classification techniques, but in this task, we’ll use it purely for Exploratory Data Analysis (EDA) to:
# - Understand how measurements differ across species
# - Find possible relationships for future predictive modeling

# %% [markdown]
# # 2. Dataset Loading and Initial Inspection

# %% [markdown]
# #### Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## i want to change style for better appearance and understanding
sns.set(style="whitegrid", palette="muted", font_scale=1.1)
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# #### Load the dataset

# %%
## Seaborn contains some built in datasets so i will import it from seaborn
df = sns.load_dataset('iris')

# %% [markdown]
# #### Exploring Data

# %%
# Shape of the dataset
print("Dataset shape:", df.shape)

# Column names
print("Column names:", df.columns.tolist())

# Preview first 5 rows
df.head()
# Out:
# Dataset shape: (150, 5)
# Column names: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### The dataset contains 150 samples with 5 features, including the target variable species. Each row represents measurements from a different Iris flower.

# %% [markdown]
# #### Data Types and Basic Info

# %%
df.info()             ## data is fully clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### All features are of numeric type except species, which is categorical, ideal for classification and grouping visualizations.

# %% [markdown]
# #### Basic Statistical Summary

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### This provides a summary of the central tendency, dispersion, and shape of the dataset’s distribution, useful for initial range checks and identifying anomalies.

# %% [markdown]
# # 3. Visual Exploration

# %% [markdown]
# ### Scatter Plot to Analyze Relationships Between Variables

# %%
## Lets plot scatter plot to analyze relationship between sepal_length and sepal_width with color-code the target column for better understanding

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species', style='species', s=70)
plt.title("Sepal Length vs Sepal Width by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend(title="Species")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The scatter plot reveals a separation between setosa and the other two species in terms of sepal measurements. However, versicolor and virginica show some overlap, indicating these features alone might not fully differentiate them.

# %% [markdown]
# ### Histogramt to Examine Data Distribution

# %%
# Histogram showing the distribution of petal length by species
sns.histplot(data=df, x='petal_length', hue='species', kde=True, palette='muted', edgecolor='black', bins=20)
plt.title("Distribution of Petal Length Across Species")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### The histogram reveals that setosa flowers have consistently shorter petal lengths, while virginica shows a wider spread with longer petals. The overlap between versicolor and virginica suggests that petal length could be a strong feature for differentiating species, especially setosa, but may require support from other features for full class separation.

# %% [markdown]
# # 3. Box Plot to Detect Outliers and Value Spread

# %%
# Box plot to visualize the distribution and outliers of petal width across species
sns.boxplot(hue='species', y='petal_width', data=df, palette='pastel')
plt.title("Distribution of Petal Width by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width (cm)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### This box plot highlights clear differences in petal width among the three species. setosa has consistently low petal width with no overlap but shows some outliers, while virginica shows the highest range. These differences are valuable for classification tasks, indicating that petal width is a strong distinguishing feature.

# %% [markdown]
# # 4. Conclusion and Key Insights

# %% [markdown]
# ## Summary:
# #### In this task, we explored the Iris dataset to understand the structure, distribution, and relationships between features using basic yet powerful visualizations. This exploration helps in identifying potential features that may contribute to future modeling or classification efforts.

# %% [markdown]
# ## Key Insights:
# - ### Sepal Dimensions:
#    #### The scatter plot of sepal_length vs sepal_width showed that setosa forms a separate cluster, while versicolor and virginica overlap slightly.
# - ### Petal Length Distribution:
#    #### The histogram revealed that setosa has a distinct range of petal lengths, unlike versicolor and virginica, which share some overlap suggesting the potential of petal features in classification.
# - ### Petal Width Spread:
#    #### The box plot demonstrated that petal width varies significantly across species. Setosa has consistently smaller petal widths with no overlap but some potential outliers, while virginica shows the largest spread.

# %% [markdown]
# ### Conclusion:
# #### This initial exploratory analysis confirms that petal measurements are more effective than sepal measurements in distinguishing between species. These findings provide a strong foundation for building a classification model in future tasks, such as those required in supervised learning workflows.
